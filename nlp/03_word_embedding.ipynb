# %%
import torch
from tensorflow.keras.preprocessing.text import Tokenizer
from torch.utils.tensorboard import SummaryWriter
import jieba
import torch.nn as nn
import pkg_resources

# 实验：nn.Embedding层词向量可视化分析
# 1 对句子分词 word_list
# 2 对句子word2id求my_token_list，对句子文本数值化sentence2id
# 3 创建nn.Embedding层，查看每个token的词向量数据
# 4 创建SummaryWriter对象, 可视化词向量
#   词向量矩阵embd.weight.data 和 词向量单词列表my_token_list添加到SummaryWriter对象中
#   summarywriter.add_embedding(embd.weight.data, my_token_list)
# 5 通过tensorboard观察词向量相似性
# 6 也可通过程序，从nn.Embedding层中根据idx拿词向量


# 1 对句子分词 word_list
sentence1 = "传智教育是一家上市公司，旗下有黑马程序员品牌。我是在黑马这里学习人工智能"
sentence2 = "我爱自然语言处理"
sentences = [sentence1, sentence2]

word_list = []
for s in sentences:
    word_list.append(jieba.lcut(s))
print(word_list)

mytokenizer = Tokenizer()
mytokenizer.fit_on_texts(word_list)  # 训练分词器


# 得出去重后的分词词汇索引
print("index_word--->", mytokenizer.index_word)
print("word_index--->", mytokenizer.word_index)

# 打印文本数值化以后的句子
sentence2id = mytokenizer.texts_to_sequences(word_list)
print("sentence2id--->", sentence2id, len(sentence2id))

# 打印my_token_list
my_token_list = mytokenizer.index_word.values()
print("my_token_list--->", my_token_list)


# 创建nn.Embedding层
# num_embeddings: 词汇表大小，即唯一单词的数量
# embedding_dim: 每个单词的词向量维度
embd = nn.Embedding(num_embeddings=len(my_token_list), embedding_dim=8)
print("embd--->", embd)
print('nn.Embedding层词向量矩阵-->', embd.weight.data, embd.weight.data.shape, type(embd.weight.data))

# 查看词向量表
for idx in range(len(mytokenizer.index_word)):
    output = embd(torch.tensor(idx))
    print("%4s" % (mytokenizer.index_word[idx + 1]), output.detach().numpy())

# 创建SummaryWriter对象 词向量矩阵embd.weight.data 和 词向量单词列表my_token_list
# 通过tensorboard观察词向量相似性
# cd 程序的当前目录下执行下面的命令
# 启动tensorboard服务 tensorboard --logdir=runs --host 0.0.0.0
# 通过浏览器，查看词向量可视化效果 http://127.0.0.1:6006

# 处理版本兼容问题
# import tensorflow as tf
# import tensorboard as tb
# tf.io.gfile = tb.compat.tensorflow_stub.io.gfile

# summarywriter = SummaryWriter(log_dir="runs")
# summarywriter.add_embedding(embd.weight.data, list(my_token_list))
# summarywriter.close()
# Out:
# [['传智', '教育', '是', '一家', '上市公司', '，', '旗下', '有', '黑马', '程序员', '品牌', '。', '我', '是', '在', '黑马', '这里', '学习', '人工智能'], ['我', '爱', '自然语言', '处理']]
# index_word---> {1: '是', 2: '黑马', 3: '我', 4: '传智', 5: '教育', 6: '一家', 7: '上市公司', 8: '，', 9: '旗下', 10: '有', 11: '程序员', 12: '品牌', 13: '。', 14: '在', 15: '这里', 16: '学习', 17: '人工智能', 18: '爱', 19: '自然语言', 20: '处理'}
# word_index---> {'是': 1, '黑马': 2, '我': 3, '传智': 4, '教育': 5, '一家': 6, '上市公司': 7, '，': 8, '旗下': 9, '有': 10, '程序员': 11, '品牌': 12, '。': 13, '在': 14, '这里': 15, '学习': 16, '人工智能': 17, '爱': 18, '自然语言': 19, '处理': 20}
# sentence2id---> [[4, 5, 1, 6, 7, 8, 9, 10, 2, 11, 12, 13, 3, 1, 14, 2, 15, 16, 17], [3, 18, 19, 20]] 2
# my_token_list---> dict_values(['是', '黑马', '我', '传智', '教育', '一家', '上市公司', '，', '旗下', '有', '程序员', '品牌', '。', '在', '这里', '学习', '人工智能', '爱', '自然语言', '处理'])
# embd---> Embedding(20, 8)
# nn.Embedding层词向量矩阵--> tensor([[-0.7208, -0.2897,  0.4013,  0.9422,  0.3990,  0.1037,  1.1414, -1.7417],
#         [-0.5864,  0.5073,  0.1749,  0.7111,  0.2690, -1.1996, -0.6915, -1.0376],
#         [-0.8228,  3.1366, -1.1022, -0.6844,  0.2806, -0.3809, -0.8778, -0.4130],
#         [ 0.4692, -0.6885, -1.7964,  1.5583,  0.7773,  0.1294, -1.3024, -0.5402],
#         [ 1.3972, -2.3802, -0.7317, -0.8693, -0.7104, -1.1077, -0.4076,  0.3763],
#         [ 0.2424, -1.4864, -0.9354,  0.0661,  0.4479,  0.5396, -0.7179,  0.0231],
#         [-0.4760, -0.1798,  1.1806,  0.5005,  1.1630, -1.2450, -1.7029, -0.6146],
#         [-1.5440,  0.2046, -0.8308,  0.5438,  0.2240, -0.0888, -0.3302, -0.1984],
#         [ 2.4358, -0.3587,  0.5505,  1.1984,  0.1178,  0.0372,  0.0387,  0.1585],
#         [ 1.7013,  0.8449,  0.2912, -1.2855,  0.7319,  1.2492,  0.1708, -0.9279],
#         [-1.0481,  1.2926,  0.4108, -0.2414, -0.6360,  0.8000,  1.4464,  0.5358],
#         [ 0.5800, -0.9654, -0.5379, -3.1107,  0.4609,  0.5810, -1.2869,  0.6764],
#         [ 0.2545,  0.4189,  0.0952, -0.2904,  0.3078, -1.1286, -0.7161,  0.5325],
#         [-0.4967, -0.6049,  0.7118, -1.1492,  0.5919, -0.8327, -0.2457, -1.1396],
#         [ 0.8957, -0.0562,  0.0254, -0.3198, -0.7697, -0.2405, -0.2839,  0.6401],
#         [-0.0897,  1.3272,  0.6563,  0.7406, -0.2636, -0.8066, -0.6082,  0.7660],
#         [-1.6837,  0.9163,  0.9631,  0.3397, -0.6995, -1.3024, -0.2730,  0.3216],
#         [-0.9262, -0.1008, -0.4321,  2.0442,  1.0492, -0.0106, -0.6599,  0.2653],
#         [ 0.6800, -2.2068, -1.1204,  0.0464,  1.3391, -0.6248,  1.5682, -0.5969],
#         [ 0.2579,  0.2809,  0.7160,  0.4728, -1.6810,  0.7279,  0.7836,  0.6409]]) torch.Size([20, 8]) <class 'torch.Tensor'>
#    是 [-0.7207649  -0.28969285  0.40133262  0.94224447  0.3990138   0.10365545
#   1.1413864  -1.7416526 ]
#   黑马 [-0.5863563   0.50732714  0.17488065  0.7111316   0.2689515  -1.199596
#  -0.6915158  -1.0376343 ]
#    我 [-0.8227604   3.1365716  -1.10221    -0.684434    0.280588   -0.3809429
#  -0.87776643 -0.41303256]
#   传智 [ 0.46918517 -0.6884587  -1.7964306   1.5582786   0.7773383   0.12936375
#  -1.3024124  -0.5401844 ]
#   教育 [ 1.397232   -2.3801703  -0.7316807  -0.86931825 -0.71035373 -1.1076816
#  -0.40763795  0.37629804]
#   一家 [ 0.24242821 -1.4864364  -0.93535143  0.06610887  0.4478983   0.53956836
#  -0.717914    0.02308514]
# 上市公司 [-0.47603944 -0.17978105  1.1806397   0.5004825   1.1629764  -1.2449702
#  -1.7028683  -0.61455065]
#    ， [-1.5440489   0.20455445 -0.8308034   0.54384     0.22396624 -0.08882417
#  -0.33017194 -0.19839872]
#   旗下 [ 2.4358168  -0.35868853  0.5504826   1.1983614   0.1177681   0.03723542
#   0.03874998  0.15853538]
#    有 [ 1.7013061   0.8448578   0.29116857 -1.2855349   0.7319393   1.2491754
#   0.17076327 -0.9279374 ]
#  程序员 [-1.0481036   1.2925547   0.41076106 -0.24144316 -0.63598424  0.7999756
#   1.4464042   0.5357857 ]
#   品牌 [ 0.5800393  -0.9653736  -0.5378586  -3.1106606   0.46093392  0.5810073
#  -1.2869182   0.6763791 ]
#    。 [ 0.25451112  0.41890782  0.09518018 -0.29040298  0.30780345 -1.1285979
#  -0.7160924   0.5324804 ]
#    在 [-0.4967121  -0.60490113  0.7117897  -1.1492014   0.5918691  -0.83274615
#  -0.24565724 -1.1396458 ]
#   这里 [ 0.8957258  -0.05619405  0.02540439 -0.3198056  -0.7696884  -0.2404512
#  -0.2838852   0.6401463 ]
#   学习 [-0.08972888  1.3271731   0.6562814   0.74061394 -0.26364318 -0.8066178
#  -0.6081616   0.7659794 ]
# 人工智能 [-1.6836509   0.9163115   0.96310866  0.33971453 -0.69954807 -1.3023878
#  -0.27301446  0.32159337]
#    爱 [-0.9261926  -0.10075519 -0.4320641   2.044245    1.0492136  -0.01058793
#  -0.6598864   0.26526535]
# 自然语言 [ 0.68000895 -2.2067595  -1.1203697   0.04640161  1.3390517  -0.6248314
#   1.5681587  -0.59691525]
#   处理 [ 0.25787202  0.28088102  0.7160204   0.4727787  -1.6810251   0.72788167
#   0.7836381   0.64091206]
